# %%
from random import randint
import numpy as np
from math import inf
from loaddata import *
import time

# %%
df = load_data('datasets/capture20110811.pcap.netflow.labeled')
df.head()
# Out:
#     Date_flow         start  Durat Prot Flags  Tos  Packets  Bytes  Flows  \
# 0  2011-08-11  10:10:00.003  0.967  UDP   INT    0        2    135      1
# 1  2011-08-11  10:10:00.003  0.967  UDP   INT    0        2    276      1
# 2  2011-08-11  10:10:00.006  0.000  UDP   INT    0        1     62      1
# 3  2011-08-11  10:10:00.008  0.000  UDP   INT    0        1     78      1
# 4  2011-08-11  10:10:00.009  0.000  UDP   INT    0        1     72      1
#
#         Label           src_ip src_port         dst_ip dst_port
# 0  Background       89.31.8.11    23929  147.32.84.229    13363
# 1  Background    147.32.84.229    13363     89.31.8.11    23929
# 2  Background     208.88.186.6    34042  147.32.84.229    13363
# 3  Background    92.118.218.77    55246  147.32.84.229    13363
# 4  Background  182.185.139.181    10223  147.32.84.229    13363

# %%
class CountMinSketch():
    
    # Initialization
    def __init__(self, buckets, d):
        self.d = d
        self.buckets = buckets
        # xor used for generating different hash functions
        self.xor = [randint(0, 100000) for i in range(d)]
        # table of size(buckets,d)
        self.table = np.zeros(shape=(d, buckets))

    # Add item into sketch
    def add_item(self, item):
        # Get results from different hashes
        hash_value = hash(item)
        hash_values = [hash_value^self.xor[i] for i in range(self.d)]
        
        for i, val in enumerate(hash_values):
            column = val % self.buckets
            self.table[i, column] += 1
    
    # Check how many times item in sketch
    def check_item(self, item):
        hash_value = hash(item)
        hash_values = [hash_value^self.xor[i] for i in range(self.d)]
        
        min_freq = inf
        for i, val in enumerate(hash_values):
            column = val % self.buckets
            
            if(self.table[i, column] < min_freq):
                min_freq = self.table[i, column]
        
        return min_freq

# %%
def run_sketch(seq, buckets, d):
    print("---------- SKETCH with bins = %d d = %d ----------" % (buckets, d))
    
    # Create sketch
    cms = CountMinSketch(buckets, d)
    
    # Prepare sketch
    start_time = time.time()
    for ip in seq:
        cms.add_item(ip)
    print("Take %s seconds to build sketch" % (time.time() - start_time))
        
    # Test sketch
    ips = list(set(seq))
    count = np.zeros(len(ips))

    # Check their esitimated occurrence
    for idx, ip in enumerate(ips):
        count[idx] = cms.check_item(ip)

    sorted_idx = np.argsort(count)
    for i in range(10):
        idx = sorted_idx[-i-1]
        print("IP: %s, count: %d" % (ips[idx], count[idx]))

# %%
host_ip = '147.32.84.165'
seq = load_ip_sequence(df, host_ip)

parameters = []
for bins in [20, 50, 100, 200, 500]:
    for d in [3, 5, 8]:
        parameters.append((bins, d))
    
for vals in parameters:
    run_sketch(seq, vals[0], vals[1])
# Out:
# ---------- SKETCH with bins = 20 d = 3 ----------
# Take 0.5180401802062988 seconds to build sketch
# IP: 158.35.238.238, count: 7905
# IP: 193.23.181.44, count: 7905
# IP: 168.61.70.66, count: 7711
# IP: 194.106.220.35, count: 7711
# IP: 184.82.155.107, count: 7711
# IP: 68.202.89.226, count: 7711
# IP: 216.178.72.158, count: 7711
# IP: 147.32.96.45, count: 6076
# IP: 46.98.83.57, count: 6076
# IP: 154.32.105.132, count: 6076
# ---------- SKETCH with bins = 20 d = 5 ----------
# Take 0.7513084411621094 seconds to build sketch
# IP: 193.23.181.44, count: 7289
# IP: 174.37.196.55, count: 5898
# IP: 184.191.34.121, count: 5009
# IP: 112.205.111.114, count: 5009
# IP: 196.0.35.154, count: 4515
# IP: 46.4.36.120, count: 4515
# IP: 68.67.185.209, count: 4515
# IP: 168.95.6.53, count: 4515
# IP: 157.205.238.165, count: 4515
# IP: 85.119.248.7, count: 4515
# ---------- SKETCH with bins = 20 d = 8 ----------
# Take 1.1169641017913818 seconds to build sketch
# IP: 193.23.181.44, count: 6986
# IP: 216.178.72.158, count: 4720
# IP: 155.212.33.146, count: 4720
# IP: 67.15.185.102, count: 4694
# IP: 20.132.170.5, count: 4694
# IP: 27.255.33.216, count: 4681
# IP: 174.37.196.55, count: 4681
# IP: 174.128.246.102, count: 4447
# IP: 67.19.72.206, count: 4329
# IP: 174.143.82.64, count: 4280
# ---------- SKETCH with bins = 50 d = 3 ----------
# Take 0.47479867935180664 seconds to build sketch
# IP: 193.23.181.44, count: 6625
# IP: 174.128.246.102, count: 4271
# IP: 212.103.213.179, count: 4271
# IP: 85.158.140.211, count: 4271
# IP: 195.113.232.98, count: 4248
# IP: 174.37.196.55, count: 3894
# IP: 64.59.192.8, count: 3729
# IP: 202.9.159.34, count: 3654
# IP: 173.236.31.226, count: 3608
# IP: 209.85.148.103, count: 3608
# ---------- SKETCH with bins = 50 d = 5 ----------
# Take 0.6654171943664551 seconds to build sketch
# IP: 193.23.181.44, count: 6515
# IP: 174.128.246.102, count: 4235
# IP: 174.37.196.55, count: 3813
# IP: 184.154.89.154, count: 3762
# IP: 67.19.72.206, count: 3523
# IP: 173.236.31.226, count: 3503
# IP: 72.20.15.61, count: 3299
# IP: 46.4.36.120, count: 3257
# IP: 147.32.80.9, count: 1811
# IP: 196.192.41.18, count: 1207
# ---------- SKETCH with bins = 50 d = 8 ----------
# Take 1.0657334327697754 seconds to build sketch
# IP: 193.23.181.44, count: 6606
# IP: 174.128.246.102, count: 4210
# IP: 174.37.196.55, count: 3852
# IP: 173.236.31.226, count: 3647
# IP: 184.154.89.154, count: 3472
# IP: 46.4.36.120, count: 3398
# IP: 67.19.72.206, count: 3297
# IP: 72.20.15.61, count: 3235
# IP: 147.32.80.9, count: 1642
# IP: 212.117.171.138, count: 1079
# ---------- SKETCH with bins = 100 d = 3 ----------
# Take 0.48043179512023926 seconds to build sketch
# IP: 193.23.181.44, count: 6498
# IP: 174.128.246.102, count: 4152
# IP: 174.37.196.55, count: 3978
# IP: 173.236.31.226, count: 3538
# IP: 67.19.72.206, count: 3384
# IP: 184.154.89.154, count: 3373
# IP: 46.4.36.120, count: 3264
# IP: 72.20.15.61, count: 3160
# IP: 65.254.254.50, count: 1740
# IP: 65.101.196.37, count: 1740
# ---------- SKETCH with bins = 100 d = 5 ----------
# Take 0.7597301006317139 seconds to build sketch
# IP: 193.23.181.44, count: 6503
# IP: 174.128.246.102, count: 4216
# IP: 174.37.196.55, count: 3757
# IP: 173.236.31.226, count: 3493
# IP: 184.154.89.154, count: 3480
# IP: 67.19.72.206, count: 3283
# IP: 46.4.36.120, count: 3278
# IP: 72.20.15.61, count: 3168
# IP: 147.32.80.9, count: 1605
# IP: 212.117.171.138, count: 1021
# ---------- SKETCH with bins = 100 d = 8 ----------
# Take 0.998530387878418 seconds to build sketch
# IP: 193.23.181.44, count: 6475
# IP: 174.128.246.102, count: 4130
# IP: 174.37.196.55, count: 3740
# IP: 173.236.31.226, count: 3451
# IP: 184.154.89.154, count: 3380
# IP: 67.19.72.206, count: 3283
# IP: 46.4.36.120, count: 3189
# IP: 72.20.15.61, count: 3152
# IP: 147.32.80.9, count: 1644
# IP: 212.117.171.138, count: 1004
# ---------- SKETCH with bins = 200 d = 3 ----------
# Take 0.48215532302856445 seconds to build sketch
# IP: 193.23.181.44, count: 6459
# IP: 174.128.246.102, count: 4113
# IP: 174.37.196.55, count: 3720
# IP: 173.236.31.226, count: 3422
# IP: 208.81.192.129, count: 3422
# IP: 184.154.89.154, count: 3382
# IP: 67.19.72.206, count: 3244
# IP: 4.78.154.138, count: 3244
# IP: 46.4.36.120, count: 3164
# IP: 72.20.15.61, count: 3128
# ---------- SKETCH with bins = 200 d = 5 ----------
# Take 0.722097635269165 seconds to build sketch
# IP: 193.23.181.44, count: 6464
# IP: 174.128.246.102, count: 4117
# IP: 174.37.196.55, count: 3735
# IP: 173.236.31.226, count: 3430
# IP: 184.154.89.154, count: 3401
# IP: 67.19.72.206, count: 3241
# IP: 46.4.36.120, count: 3158
# IP: 72.20.15.61, count: 3123
# IP: 147.32.80.9, count: 1595
# IP: 212.117.171.138, count: 983
# ---------- SKETCH with bins = 200 d = 8 ----------
# Take 0.8816344738006592 seconds to build sketch
# IP: 193.23.181.44, count: 6453
# IP: 174.128.246.102, count: 4114
# IP: 174.37.196.55, count: 3721
# IP: 173.236.31.226, count: 3412
# IP: 184.154.89.154, count: 3356
# IP: 67.19.72.206, count: 3240
# IP: 46.4.36.120, count: 3161
# IP: 72.20.15.61, count: 3130
# IP: 147.32.80.9, count: 1593
# IP: 212.117.171.138, count: 980
# ---------- SKETCH with bins = 500 d = 3 ----------
# Take 0.4791073799133301 seconds to build sketch
# IP: 193.23.181.44, count: 6466
# IP: 174.128.246.102, count: 4103
# IP: 174.37.196.55, count: 3707
# IP: 173.236.31.226, count: 3412
# IP: 184.154.89.154, count: 3344
# IP: 67.19.72.206, count: 3232
# IP: 46.4.36.120, count: 3153
# IP: 72.20.15.61, count: 3113
# IP: 147.32.80.9, count: 1578
# IP: 212.117.171.138, count: 971
# ---------- SKETCH with bins = 500 d = 5 ----------
# Take 0.7453336715698242 seconds to build sketch
# IP: 193.23.181.44, count: 6444
# IP: 174.128.246.102, count: 4105
# IP: 174.37.196.55, count: 3709
# IP: 173.236.31.226, count: 3412
# IP: 184.154.89.154, count: 3350
# IP: 67.19.72.206, count: 3228
# IP: 46.4.36.120, count: 3154
# IP: 72.20.15.61, count: 3113
# IP: 147.32.80.9, count: 1577
# IP: 212.117.171.138, count: 970
# ---------- SKETCH with bins = 500 d = 8 ----------
# Take 1.161961317062378 seconds to build sketch
# IP: 193.23.181.44, count: 6444
# IP: 174.128.246.102, count: 4103
# IP: 174.37.196.55, count: 3709
# IP: 173.236.31.226, count: 3414
# IP: 184.154.89.154, count: 3344
# IP: 67.19.72.206, count: 3233
# IP: 46.4.36.120, count: 3152
# IP: 72.20.15.61, count: 3113
# IP: 147.32.80.9, count: 1580
# IP: 212.117.171.138, count: 969
